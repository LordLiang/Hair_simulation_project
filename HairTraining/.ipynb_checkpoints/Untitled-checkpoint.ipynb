# %%
# %run nCache -f "../../maya cache/03074/hair_nRigidShape1.xml"
# Out:
# Channel Name =nRigidShape1,type=FloatVectorArray,interp=positions,sampleType=Regular,rate=250,start=250,end=50000
#
# Channel Name =hairSystemShape1_hairCounts,type=FloatArray,interp=hairCounts,sampleType=Regular,rate=250,start=250,end=50000
#
# Channel Name =hairSystemShape1_vertexCounts,type=FloatArray,interp=vertexCounts,sampleType=Regular,rate=250,start=250,end=50000
#
# Channel Name =hairSystemShape1_positions,type=FloatVectorArray,interp=positions,sampleType=Regular,rate=250,start=250,end=50000
#
# *******************************************************************************
#
# Maya Cache version 2.000000, Format = OneFile
#
# The cache was originally created at 24 FPS
#
# Cache has 4 channels, starting at time 0.041667 seconds and ending at 8.333333 seconds
#
# Channelname =nRigidShape1, type=FloatVectorArray, interpretation =positions, sampling Type = Regular
#
# sample rate (for regular sample type only) = 24.000000 FPS
#
# ...
